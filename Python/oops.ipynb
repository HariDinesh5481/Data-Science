# %%
class car:
   
    def __init__(self,brand,price):
        self.brand = brand
        self.price = price
c1=car('audi',50000)
c2=car('Porche',100000)
c1.brand
# Out:
# 'audi'

# %%
class car:
   
    def __init__(self,brand,price):
        self.brand = brand
        self.price = price
    
    def show(self):
        print(self.brand,self.price)
s1 = car('Martin',800000)
s1.show()
# Out:
# Martin 800000

# %%
class car:
   company = 'Tata'
   def __init__(self,brand,price):
        self.brand = brand
        self.price = price
d1=car('swaraj',50000)
d2=car('rover',700000)
d1.company
d2.company
# Out:
# 'Tata'

# %%
class clg:
    college = 'PIT'
    def __init__(self,name):
        self.name = name 
n1 = clg('hari')
n2=clg('Vasu')
n1.name
n1.college
n2.name
n2.college
# Out:
# 'PIT'

# %% [markdown]
# LEVEL 2

# %%
class student:

    def __init__(self,name,marks):
        self.name = name
        self.marks = marks

    def show(self):
        print(self.name,self.marks)
s1=student('hari',50)
s2 = student('varun',60)
print(s1.name,s1.marks)
s2.show()
# Out:
# hari 50
# varun 60

# %%
class stu:
    clog = 'college'
    @classmethod
    def change_clg(cls,name):
        cls.clog = name
    
    
stu.change_clg('klm')
print(stu.clog)
# Out:
# klm

# %%
class stude:
    @staticmethod
    def is_pass(marks):
        if marks > 40:
            print('pass')
        else:
            print('fail')
stude.is_pass(50)
# Out:
# pass

# %% [markdown]
# level 3

# %%
class Demo:
    def show(self):
        print("Hello")

d = Demo()
d.show()
# Out:
# Hello

# %%
class Bank:
    def __init__(self,name,balance):
        self.name = name
        self.balance = balance
    def deposit(self,amount):
        self.balance = self.balance + amount
        return self.balance
        print(f"your new balance is {self.balance}")
    def withdraw(self,amount):
        if amount > self.balance :
            print("Insufficient funds")
        else :
            self.balance = self.balance - amount
        return self.balance
acc = Bank('Hari',4000)
acc.withdraw(20)
# Out:
# 3980

# %%
class student1:
    school = "ABC"
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks 
    def show(self):
        print(self.name,self.marks)
    @classmethod
    def change_name(cls,sch_name):
        cls.school = sch_name
        print(f"new school name is {sch_name}")
    @staticmethod
    def grade(marks):
        if marks >=90:
            print("You got A grade")
        elif marks >50 and marks <90:
            print("You got B grade")
        else:
            print("Work hard,you are failed")

# %%
s1 = student1('hari',75)
s1.grade(75)
# Out:
# You got B grade

# %%
class STudent:
    def __init__(self,name,marks):
        self.name = name
        self.marks = marks
    def total_marks(marks):
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 Student.c1
#
# AttributeError: type object 'Student' has no attribute 'c1'
