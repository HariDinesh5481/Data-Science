# %%
import pandas as pd

# %%
data = [2,5,7]
pd.DataFrame(l)
# Out:
#    0
# 0  2
# 1  5
# 2  7

# %%
age = [28,32,35,24]
df = pd.DataFrame(age,index= ["A","B","C","D"],columns=["age"])

# %%
df
# Out:
#    age
# A   28
# B   32
# C   35
# D   24
