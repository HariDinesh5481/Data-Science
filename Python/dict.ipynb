# %%
#Create a dictionary of student names and their ages
d = {'Hari':23, 'Vishnu':24 ,'Sumanth':23}
# Out:
# dict

# %%
#Add a new key-value pair to dictionary {'a': 1, 'b': 2, 'c': 3}
v= {'a': 1, 'b': 2, 'c': 3}
v['e'] = 4
v
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'e': 4}

# %%
#Get all keys from dictionary {'name': 'John', 'age': 25, 'city': 'New York'}
dict = {'name': 'John', 'age': 25, 'city': 'New York'}
dict.keys()
# Out:
# dict_keys(['name', 'age', 'city'])

# %%
#Get all values from dictionary {'python': 3, 'java': 2, 'c++': 1}
va ={'python': 3, 'java': 2, 'c++': 1}
va.values()
# Out:
# dict_values([3, 2, 1])

# %%
#Check if key 'age' exists in {'name': 'Alice', 'age': 30, 'city': 'London'}
v = {'name': 'Alice', 'age': 30, 'city': 'London'}
print('age' in v)
# Out:
# True

# %%
#Remove key 'temp' from {'a': 1, 'b': 2, 'temp': 3, 'c': 4}
b = {'a': 1, 'b': 2, 'temp': 3, 'c': 4}
b.pop('temp')
b
# Out:
# {'a': 1, 'b': 2, 'c': 4}

# %%
#Find the sum of all values in {'math': 85, 'science': 92, 'english': 78}
v = {'math': 85, 'science': 92, 'english': 78}
sum = 0
for i in v.values():
    sum = sum + i
sum
# Out:
# 255

# %%
# Create a dictionary with squares of numbers 1 to 5
squares = {x: x**2 for x in range(1, 6)}
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
#Count frequency of each character in string 'hello'
s = "hello"
freq = {}

for char in s:
    freq[char] = freq.get(char, 0) + 1

print(freq)
# Out:
# {'h': 1, 'e': 1, 'l': 2, 'o': 1}

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'c': 3, 'd': 4}

d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
person_dict = {
    'person': {
        'name': 'Alice',
        'age': 25
    }
}

print(person_dict)
# Out:
# {'person': {'name': 'Alice', 'age': 25}}

# %%
n = [1,2,2,3,3,3,4]
freq = {}
for i in n:
    freq[i] = freq.get(i,0)+1
freq
# Out:
# {1: 1, 2: 2, 3: 3, 4: 1}

# %%
s  = "data science is data driven"
words = s.split()
freqq = {}
for i in words:
    freqq[i] = freqq.get(i,0)+1
freqq
# Out:
# {'data': 2, 'science': 1, 'is': 1, 'driven': 1}

# %%
#Access nested value 'name' from {'person': {'name': 'Alice', 'age': 25}}
n = {'person': {'name': 'Alice', 'age': 25}}
h = n['person']['name']
h
# Out:
# 'Alice'

# %%
#Create a dictionary with list values: {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}")
#n = {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}
m = {'fruits' : ['apple', 'banana'], 'colors' : ['red', 'blue']}
m
# Out:
# {'fruits': ['apple', 'banana'], 'colors': ['red', 'blue']}

# %%
#Add 'orange' to the 'fruits' list in nested dictionary
m['fruits'].append('orange')
m
# Out:
# {'fruits': ['apple', 'banana', 'orange', 'orange'], 'colors': ['red', 'blue']}

# %%
m['fruits'].pop(2)
# Out:
# 'orange'

# %%
#Create a dictionary with tuple values: {'coordinates': (10, 20), 'rgb': (255, 0, 0)}
#n = {'coordinates': (10, 20), 'rgb': (255, 0, 0)}
m = {'coordinate':(10,20), 'rgb' : (255,0,0)}
m
# Out:
# {'coordinate': (10, 20), 'rgb': (255, 0, 0)}

# %%
#Extract first coordinate from nested tuple
m['coordinate'][0]
# Out:
# 10

# %%
#Create a dictionary with set values: {'vowels': {'a', 'e', 'i'}, 'consonants': {'b', 'c', 'd'}}
b = {'vowels' : {'a','e',i}, 'consonants':{'b','c','d'}}
b
# Out:
# {'vowels': {'a', 'driven', 'e'}, 'consonants': {'b', 'c', 'd'}}

# %%
#Add 'o' to vowels set in nested dictionary
b['vowels'].add('o')

# %%
#Create a 3-level nested dictionary: {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}
d = {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}
d
# Out:
# {'company': {'department': {'employee': {'name': 'John', 'id': 123}}}}

# %%
#Access employee name from 3-level nested dictionary
d['company']['department']['employee']['name']
# Out:
# 'John'

# %%
#Create a dictionary with mixed data types: {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}
d = {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}
d
# Out:
# {'int': 42, 'float': 3.14, 'str': 'hello', 'bool': True}

# %%
#Check data type of each value in mixed dictionary
for i in d.values():
    print(type(i))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
