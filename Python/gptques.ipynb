# %%
#1
x = int(input("enter a number :"))
if x >=1:
    print(f"{x} is a positive number ")
elif x ==0:
    print("x is zero")
else:
    print(f"{x} is a negavite number")
# Out:
# 5 is a positive number

# %%
#2
x = int(input("enter a number : "))
if x% 2 ==0 :
    print(f"{x} is a even number ")
else :
    print(f"{x} is odd number")
# Out:
# 5 is odd number

# %%
x = 15
a =14
b= 113
if x>a and x>b:
    print(f"{x} is the greatest amoung 3 numbers")
elif a>x and a>b:
    print(f"{a} is the greatest amoung 3 numbers")
else:
    print(f"{b} is the greatest amoung 3 numbers")
# Out:
# 113 is the greatest amoung 3 numbers

# %%
y = int(input("enter the year :"))
if (y % 4 == 0 and y % 100 != 0) or y % 400 == 0:
    print("y is a leap year")
else :
    print("its not a leap year")
# Out:
# y is a leap year

# %%
vowel = ['a','e','i','o','u']
x = input("enter a charcter: ")
if x in vowel:
    print(f"{x} is a vowel")
else:
    print("its not a vowel")
# Out:
# e is a vowel

# %%
x = int(input("enter a number :"))
if x%3==0 and x%5==0:
    print("FIZZBUZZ")
elif x%3==0:
    print("FIZZ")
elif x%5==0:
    print("BUZZ")
else:
    print("num is not divisible by any ")
# Out:
# FIZZBUZZ

# %%
marks = int(input("enter marks : "))
if marks>= 90 :
    print("you got A")
elif marks>=75 and marks<90:
    print("you got B")
elif 50<marks<75 :
    print("you got C")
else:
    print("your are failed")
# Out:
# your are failed

# %%
a=int(input("enter the value : "))
b = int(input("enter the value : "))
c=int(input("enter the value : "))
if a == b == c:
    print("its an equilateral triangle ")
elif a==b or b==c or a==c:
    print("its a iscoceles triangle")
else :
    print("its scalene triangle ")
# Out:
# its a iscoceles triangle

# %%
username = "Hari"
password = 123
x = input("enter username :")
y = int(input("enter password:"))
if x == username and y == password:
    print("login success")
else:
    print("login failed")
# Out:
# login success

# %%
x = int(input("enter a number :"))
if x in range(1,11):
    print("low")
elif x in range(11,51):
    print("medium")
elif x in range(51,101):
    print("high")
else :
    print("out of range ")
# Out:
# low

# %%
#11

# %%
#12
x = input("enter the number : ")
if x == x[::-1]:
    print(f"{x} is a palindrome ")
else:
    print(f"{x} is not a palindrome")
# Out:
# 123 is not a palindrome

# %%
#13
x = int(input("enter the total price : "))
if x in range(0,101):
    print("its 2rs per unit")
    print(x*2)
elif x in range(101,201):
    print("its 5rs per unit ")
    print(x*5)
elif x in range(201,301):
    print("its 8rs per unit")
    print(x*8)
else:
    print("its 10rs per unit")
    print(x*10)
# Out:
# its 8rs per unit
# 2000

# %%
balance = 5000
withdrawl = int(input("enter the amount:"))
min_balance = 500
if withdrawl <= (balance - min_balance) and withdrawl%100 ==0 :
    print("take your amount")
else :
    print("cant process at the moment")
# Out:
# cant process at the moment

# %%
a = input("enter rock or paper or scissors")
b = input("enter rock or paper or scissors")
if 'rock'  and 'paper' :
    print("paper wins")
elif 'rock' and 'scissors':
    print("rock wins")
elif 'paper' and 'scissors':
    print("scissors wins")
# Out:
# paper wins

# %%
# Out:
# Paper wins
